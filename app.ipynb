# %%
# ========================
# 📘 Importing Libraries
# ========================
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import string
import joblib

# %%
# ========================
# 📂 Loading the Datasets
# ========================
fake = pd.read_csv('Fake.csv')
true = pd.read_csv('True.csv')

print("Fake news shape:", fake.shape)
print("True news shape:", true.shape)

fake.head()
# Out:
# Fake news shape: (23481, 4)
# True news shape: (21417, 4)
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
# ========================
# 🧾 Adding Labels
# ========================
fake['label'] = 0  # 0 → Fake
true['label'] = 1  # 1 → True

# Combine datasets
data = pd.concat([fake, true], axis=0)
data = data.sample(frac=1).reset_index(drop=True)  # Shuffle data

data.head()
# Out:
#                                                title  \
# 0  U.S. Supreme Court turns away companies in Cal...
# 1  Investors buoyed by Trump's readiness to move ...
# 2  LOL! NYC COLLEGE Tells NYPD To Use Bathroom At...
# 3   Trump Ally Curt Schilling Blasts ‘Horrifying’...
# 4  Russian opposition leader's fraud conviction a...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The U.S. Supreme Court ...  politicsNews
# 1  (Reuters) - Wall Street’s predilection for a g...  politicsNews
# 2  Brooklyn College is advising New York City pol...     left-news
# 3  Former Red Sox pitcher Curt Schilling, the hos...          News
# 4  STRASBOURG, France (Reuters) - Europe s top hu...     worldnews
#
#                 date  label
# 0  October 11, 2016       1
# 1    March 24, 2017       1
# 2       Nov 21, 2017      0
# 3    October 1, 2017      0
# 4  October 17, 2017       1

# %%
# ========================
# 🧹 Cleaning the Text
# ========================
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)  # remove brackets
    text = re.sub("\\W", " ", text)     # remove non-word chars
    text = re.sub('https?://\S+|www\.\S+', '', text)  # remove links
    text = re.sub('<.*?>+', '', text)   # remove html tags
    text = re.sub("[%s]" % re.escape(string.punctuation), "", text)  # remove punctuations
    text = re.sub("\n", "", text)       # remove newline
    text = re.sub("\w*\d\w*", "", text) # remove words with digits
    return text

data['text'] = data['text'].apply(clean_text)
data.head()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\['
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# <>:12: SyntaxWarning: invalid escape sequence '\w'
# <>:6: SyntaxWarning: invalid escape sequence '\['
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# <>:12: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\hp\AppData\Local\Temp\ipykernel_33668\2018419720.py:6: SyntaxWarning: invalid escape sequence '\['
#   text = re.sub('\[.*?\]', '', text)  # remove brackets
# C:\Users\hp\AppData\Local\Temp\ipykernel_33668\2018419720.py:8: SyntaxWarning: invalid escape sequence '\S'
#   text = re.sub('https?://\S+|www\.\S+', '', text)  # remove links
# C:\Users\hp\AppData\Local\Temp\ipykernel_33668\2018419720.py:12: SyntaxWarning: invalid escape sequence '\w'
#   text = re.sub("\w*\d\w*", "", text) # remove words with digits
#                                                title  \
# 0  U.S. Supreme Court turns away companies in Cal...
# 1  Investors buoyed by Trump's readiness to move ...
# 2  LOL! NYC COLLEGE Tells NYPD To Use Bathroom At...
# 3   Trump Ally Curt Schilling Blasts ‘Horrifying’...
# 4  Russian opposition leader's fraud conviction a...
#
#                                                 text       subject  \
# 0  washington  reuters    the u s  supreme court ...  politicsNews
# 1   reuters    wall street s predilection for a g...  politicsNews
# 2  brooklyn college is advising new york city pol...     left-news
# 3  former red sox pitcher curt schilling  the hos...          News
# 4  strasbourg  france  reuters    europe s top hu...     worldnews
#
#                 date  label
# 0  October 11, 2016       1
# 1    March 24, 2017       1
# 2       Nov 21, 2017      0
# 3    October 1, 2017      0
# 4  October 17, 2017       1

# %%
# ========================
# ✂️ Splitting Data
# ========================
X = data['text']
y = data['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))
# Out:
# Training samples: 33673
# Testing samples: 11225

# %%
# ========================
# 🔤 TF-IDF Vectorization
# ========================
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("TF-IDF matrix shape:", X_train_tfidf.shape)
# Out:
# TF-IDF matrix shape: (33673, 94674)

# %%
# ========================
# 🤖 Logistic Regression Model
# ========================
model = LogisticRegression()
model.fit(X_train_tfidf, y_train)

y_pred = model.predict(X_test_tfidf)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      5835
#            1       0.98      0.98      0.98      5390
#
#     accuracy                           0.98     11225
#    macro avg       0.98      0.98      0.98     11225
# weighted avg       0.98      0.98      0.98     11225

# %%
# ========================
# 💾 Save Model and Vectorizer
# ========================
joblib.dump(model, 'fake_news_model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')

print("✅ Model and Vectorizer saved successfully!")
# Out:
# ✅ Model and Vectorizer saved successfully!

# %%
# ========================
# 🔍 Test Prediction
# ========================
def predict_news(news_text):
    cleaned = clean_text(news_text)
    transformed = vectorizer.transform([cleaned])
    prediction = model.predict(transformed)
    return "📰 Real News" if prediction[0] == 1 else "⚠️ Fake News"

# Example test
sample = "The president announced a new education policy today."
print(predict_news(sample))
# Out:
# ⚠️ Fake News
